# %%
import pandas as pd 
from datetime import date, timedelta
import plotly.express as px
#%matplotlib inline

# %% [markdown]
# Data is available as csv files in the Johns Hopkins Github repository. You can find it in this website: https://github.com/CSSEGISandData/COVID-19/tree/master/csse_covid_19_data/csse_covid_19_daily_reports

# %%
yesterday = datetime.datetime.today() - timedelta(days=1)
year = str(yesterday.year)
month = str(yesterday.month).rjust(2, '0')
day = str(yesterday.day).rjust(2, '0')

base_url = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/"
url = base_url+month+"-"+day+"-"+year+".csv"

print("The data is last updated as of {}/{}/{}".format(day, month, year))

try: 
    df_test = pd.read_csv(url, error_bad_lines=False)
except
# Out:
# The data is last updated as of 09/04/2020

# %%
# Out:
#          FIPS     Admin2  Province_State      Country_Region  \
# 0     45001.0  Abbeville  South Carolina                  US
# 1     22001.0     Acadia       Louisiana                  US
# 2     51001.0   Accomack        Virginia                  US
# 3     16001.0        Ada           Idaho                  US
# 4     19001.0      Adair            Iowa                  US
# ...       ...        ...             ...                 ...
# 2906      NaN        NaN             NaN             Vietnam
# 2907      NaN        NaN             NaN  West Bank and Gaza
# 2908      NaN        NaN             NaN      Western Sahara
# 2909      NaN        NaN             NaN              Zambia
# 2910      NaN        NaN             NaN            Zimbabwe
#
#               Last_Update        Lat       Long_  Confirmed  Deaths  \
# 0     2020-04-09 23:02:37  34.223334  -82.461707          7       0
# 1     2020-04-09 23:02:37  30.295065  -92.414197         89       3
# ...

# %%
df = pd.read_csv("covid19/covid_19_data.csv")
df = df.groupby(by=["Country/Region", "ObservationDate"]).sum()
df.reset_index(inplace=True)#, level="Country/Region")
try:
    df.drop(["SNo"], axis=1, inplace=True)
except: 
    KeyError
    
df["Deaths/Confirmed"] = df["Deaths"] / df["Confirmed"]
df["Recovered/Confirmed"] = df["Recovered"] / df["Confirmed"]
df["Deaths/Recovered"] = df["Deaths"] / df["Recovered"]

df["Closed Cases"] = df["Deaths"] + df["Recovered"] 
df["Recovery Rate"] = df["Recovered"]  / df["Closed Cases"]
df["Death Rate"] = df["Deaths"]  / df["Closed Cases"]

df.sort_values(by=['ObservationDate'], inplace=True)
#df
df.rename(columns={"Country/Region":"Country"}, inplace=True)

# %%
df.groupby("Country").max()
df.sort_values(by=['Deaths'],ascending=False, inplace=True)
df_bool_duplicated = df.duplicated(subset="Country", keep="first")
#df.sort_values(by=['ObservationDate'],ascending=True)
max_deaths = df[~(df_bool_duplicated)]
max_deaths.reset_index(drop=True, inplace=True)
#max_deaths.head()

# %%
max_deaths_10 = max_deaths.loc[0:9]
max_deaths_10_list = max_deaths_10["Country"].to_list()

max_deaths_5 = max_deaths.loc[0:4]
max_deaths_5_list = max_deaths_5["Country"].to_list()

# %%
df_top10 = df.filter(items=max_deaths_10_list, axis="index")
df_top10= df[df["Country"].isin(max_deaths_10_list)]
df_top10 = df_top10.sort_values(by=['ObservationDate'],ascending=True)

df_top5 = df.filter(items=max_deaths_5_list, axis="index")
df_top5= df[df["Country"].isin(max_deaths_5_list)]
df_top5 = df_top5.sort_values(by=['ObservationDate'],ascending=True)

#df_top10

# %%
df_spain = df[df["Country"] == "Spain"]

# %%
df = df.sort_values(by=['ObservationDate'],ascending=True)

fig = px.scatter_geo(df, locations="Country", color="Country", locationmode="country names"
                     ,hover_name="Country", size="Confirmed",
                     animation_frame="ObservationDate", projection="natural earth")
fig.show()

# %%
df = df.sort_values(by=['ObservationDate'],ascending=True)

fig = px.scatter_geo(df, locations="Country", color="Country", locationmode="country names"
                     ,hover_name="Country", size="Confirmed",
                     animation_frame="ObservationDate", projection="natural earth")
fig.show()

# %%
fig = px.scatter(df_top10, x="ObservationDate", y="Deaths/Confirmed", 
                 color="Country", range_y=(0,0.15),size="Deaths")
fig

# %%
fig = px.scatter(df, x="Confirmed", y="Deaths", color="Country", size="Recovered")
fig

# %% [markdown]
# To do :
#     - Grapf showing the percentage of recoveres or deaths

# %%
df

# %%
df_today = df.sort_values(by=['ObservationDate'],ascending=False)
df_bool_duplicated = df_today.duplicated(subset="Country", keep="first")
df_today = df_today[~(df_bool_duplicated)]
df_today

# %%
fig = px.scatter(df_today, x="Positive Closed Percent", y="Negative Closed Percent",
                 color="Country", size="Closed Cases")
fig

# %%
df["Closed Cases"].max()

# %%
df[df["Country"] == "Mainland China"]["Closed Cases"].max()

# %%
df_spain = df[df["Country"] == "Spain"]

# %%
max_deaths_10
# Out:
#           Country ObservationDate  Confirmed   Deaths  Recovered  \
# 0           Italy      04/08/2020   139422.0  17669.0    26491.0
# 1           Spain      04/08/2020   148220.0  14792.0    48021.0
# 2              US      04/08/2020   429052.0  14695.0    23559.0
# 3          France      04/08/2020   113959.0  10887.0    21452.0
# 4              UK      04/08/2020    61474.0   7111.0      345.0
# 5            Iran      04/08/2020    64586.0   3993.0    29812.0
# 6  Mainland China      04/08/2020    81804.0   3333.0    77293.0
# 7         Germany      04/08/2020   113296.0   2349.0    46300.0
# 8     Netherlands      04/08/2020    20682.0   2255.0      272.0
# 9         Belgium      04/08/2020    23403.0   2240.0     4681.0
#
#    Deaths/Confirmed  Recovered/Confirmed  Deaths/Recovered  Closed Cases  \
# 0          0.126730             0.190006          0.666981       44160.0
# 1          0.099798             0.323985          0.308032       62813.0
# ...

# %%
df_top10 = df_top10.sort_values(by=['ObservationDate'],ascending=True)
fig = px.scatter(df_top10, x="ObservationDate", y="Death Rate", size="Confirmed", color="Country",
                title="Evolution of Death Rate over Time per Country")
fig
# Out:
# <div>
#
#
#             <div id="467508b0-c7de-430f-88c6-15771ef0f727" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("467508b0-c7de-430f-88c6-15771ef0f727")) {
#                     Plotly.newPlot(
#                         '467508b0-c7de-430f-88c6-15771ef0f727',
# ...
